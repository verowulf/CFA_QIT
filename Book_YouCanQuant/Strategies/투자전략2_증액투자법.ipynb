# %% [markdown]
# ## 투자전략 2 증액투자법

# %% [markdown]
# ### Strategy:
#
# 전체를 국채에 투자 후<br>
# 월 1회 국채에서 나온 수익으로 지수에 투자<br>
# [스타일: 자산배분]

# %% [markdown]
# 원금을 잃을 수 없는 전략 (나라가 망하지 않는 한)
#
# J.P. Morgan: *"잠이 올 만큼 주식을 팔아라"*<br>
# 주식은 심리 80% 기술 20%의 게임

# %% [markdown]
# ### Backtest results

# %%
bt = get_backtest('5a8a74d9300d7a422ada7b93')
bt.create_full_tear_sheet()
# Out:
# 100% Time: 0:00:01|###########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2002-08-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-02-16</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>186</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>6.1%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>152.4%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>5.9%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.05</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.64</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
# ...
