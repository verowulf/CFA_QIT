# %% [markdown]
# ## 투자전략 1 정률투자법

# %% [markdown]
# ### Strategy:
#
# 절반은 지수에, 나머지 절반은 국채에 투자하고<br>
# 월 1회 다시 동일비중으로 리밸런싱<br>
# [스타일: 자산배분]

# %% [markdown]
# 특정 자산군에 일정한 비중을 투자하고 주기적으로 동일한 비중으로 맞추는 전략
#
# 놀라운 점은 이렇게 간단하게 주기적으로 리밸런싱만 해도 수익이 창출!<br>
# 장기적으로 저가 매수, 고가 매도를 반복하게 되므로

# %% [markdown]
# ### Backtest results

# %%
bt = get_backtest('5a8a73008f1d2642b367904f')
bt.create_full_tear_sheet()
# Out:
# 100% Time: 0:00:01|###########################################################|
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2002-08-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-02-16</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>186</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>6.8%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>178.1%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>8.2%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.85</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.25</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
# ...
